# %%
string_value = "Hello World"
integer_value = 42
float_value = 42.21

name= "Gülizar"
age= 21
school= "Hacettepe üniversitesi"
department= "Bilgisayar mühendisliği"


print(f"Merhaba ben {name}, {age} yaşındayım. {school}'nde {department} bölümünde okuyorum. ")
# Out:
# Merhaba ben Gülizar, 21 yaşındayım. Hacettepe üniversitesi'nde Bilgisayar mühendisliği bölümünde okuyorum.
